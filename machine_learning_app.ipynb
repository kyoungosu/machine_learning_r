# %%
library(caret)
# Out:
# Warning message:
# “package ‘caret’ was built under R version 4.0.5”
# Loading required package: lattice
#
# Warning message:
# “package ‘lattice’ was built under R version 4.0.3”
# Loading required package: ggplot2
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.5”

# %%
# define the filename
filename <- "iris.csv"
# load the CSV file from the local directory
dataset <- read.csv(filename, header=FALSE)
# set the column names in the dataset
colnames(dataset) <- c("Sepal.Length","Sepal.Width","Petal.Length","Petal.Width","Species")

# %%
# create a list of 80% of the rows in the original dataset we can use for training
validation_index <- createDataPartition(dataset$Species, p=0.80, list=FALSE)
# select 20% of the data for validation
validation <- dataset[-validation_index,]
# use the remaining 80% of data to training and testing the models
dataset <- dataset[validation_index,]

# %%
# dimensions of dataset
dim(dataset)
# Out:
# [1] 120   5

# %%
# list types for each attribute
sapply(dataset, class)
# Out:
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width      Species
#    "numeric"    "numeric"    "numeric"    "numeric"  "character"

# %%
dataset$Species = as.factor(dataset$Species)

# %%
# list types for each attribute
sapply(dataset, class)
# Out:
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width      Species
#    "numeric"    "numeric"    "numeric"    "numeric"     "factor"

# %%
# take a peek at the first 5 rows of the data
head(dataset)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         Iris-setosa
# 2 4.9          3.0         1.4          0.2         Iris-setosa
# 3 4.7          3.2         1.3          0.2         Iris-setosa
# 4 4.6          3.1         1.5          0.2         Iris-setosa
# 5 5.0          3.6         1.4          0.2         Iris-setosa
# 6 5.4          3.9         1.7          0.4         Iris-setosa

# %%
# list the levels for the class
levels(dataset$Species)
# Out:
# [1] "Iris-setosa"     "Iris-versicolor" "Iris-virginica"

# %%
# summarize the class distribution
percentage <- prop.table(table(dataset$Species)) * 100
cbind(freq=table(dataset$Species), percentage=percentage)
# Out:
#                 freq percentage
# Iris-setosa     40   33.33333
# Iris-versicolor 40   33.33333
# Iris-virginica  40   33.33333

# %%
# summarize attribute distributions
summary(dataset)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.400   Min.   :2.000   Min.   :1.000   Min.   :0.1
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.3
#  Median :5.800   Median :3.000   Median :4.400   Median :1.3
#  Mean   :5.817   Mean   :3.038   Mean   :3.728   Mean   :1.2
#  3rd Qu.:6.400   3rd Qu.:3.325   3rd Qu.:5.100   3rd Qu.:1.8
#  Max.   :7.900   Max.   :4.200   Max.   :6.700   Max.   :2.5
#             Species
#  Iris-setosa    :40
#  Iris-versicolor:40
#  Iris-virginica :40

# %%
# split input and output
x <- dataset[,1:4]
y <- dataset[,5]

# %%
# boxplot for each attribute on one image
par(mfrow=c(1,4))
  for(i in 1:4) {
  boxplot(x[,i], main=names(iris)[i])
}
# Out:
# Plot with title “Petal.Width”

# %%
# barplot for class breakdown
plot(y)
# Out:
# plot without title

# %%
# scatterplot matrix
featurePlot(x=x, y=y, plot="ellipse")
# Out:
# plot without title

# %%
# box and whisker plots for each attribute
featurePlot(x=x, y=y, plot="box")
# Out:
# plot without title

# %%
# density plots for each attribute by class value
scales <- list(x=list(relation="free"), y=list(relation="free"))
featurePlot(x=x, y=y, plot="density", scales=scales)
# Out:
# plot without title

# %%
# Run algorithms using 10-fold cross validation
control <- trainControl(method="cv", number=10)
metric <- "Accuracy"

# %%
# a) linear algorithms
set.seed(7)
fit.lda <- train(Species~., data=dataset, method="lda", metric=metric, trControl=control)
# b) nonlinear algorithms
# CART
set.seed(7)
fit.cart <- train(Species~., data=dataset, method="rpart", metric=metric, trControl=control)
# kNN
set.seed(7)
fit.knn <- train(Species~., data=dataset, method="knn", metric=metric, trControl=control)
# c) advanced algorithms
# SVM
set.seed(7)
fit.svm <- train(Species~., data=dataset, method="svmRadial", metric=metric, trControl=control)
# Random Forest
set.seed(7)
fit.rf <- train(Species~., data=dataset, method="rf", metric=metric, trControl=control)
# Out:
# 1 package is needed for this model and is not installed. (kernlab). Would you like to try to install it now?
# Error: Required package is missing
# Traceback:
#
# 1. train(Species ~ ., data = dataset, method = "svmRadial", metric = metric,
#  .     trControl = control)
# 2. train.formula(Species ~ ., data = dataset, method = "svmRadial",
#  .     metric = metric, trControl = control)
# 3. train(x, y, weights = w, ...)
# 4. train.default(x, y, weights = w, ...)
# 5. checkInstall(models$library)
# 6. stop("Required package is missing", call. = FALSE)
